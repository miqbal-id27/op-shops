# %%
# Import Library
import os

## Universal Data Processing
import numpy as np
import pandas as pd

## Regular Expression for Text Data
import re

## JSON Files Manipulation
import json
from pathlib import Path

# %%
# Path
path = Path("C:/03. Other/op-shops/Datasets/opshops_with_coords.json")

# Load dataset
all_data = []

print(f"Loading file: {path}")

with open(path, "r", encoding="utf-8") as json_file:
    data = json.load(json_file)
    all_data.append(data)

print("Files loaded:", len(all_data))
print("Records in file:", len(all_data[0]) if all_data else 0)
# Out:
# Loading file: C:\03. Other\op-shops\Datasets\opshops_with_coords.json
# Files loaded: 1
# Records in file: 2297

# %%
all_data[:5]
# Out:
# [[['Koo Wee Rup and District Lions Community Opportunity Shop',
#    '290 Rossiter Road, Koo Wee Rup',
#    -38.1993407,
#    145.4912486,
#    'Mon - Fri 10am-4pm',
#    'Sat 9am-12pm',
#    'Sun 10am-3pm selected Sundays'],
#   ['Rose Lodge Opportunity Shop',
#    '42 McBride Avenue, Wonthaggi, 3996',
#    -38.6063217,
#    145.5909252,
#    'Mon - Fri 9am - 4pm',
#    'Sat 9am - 12pm'],
#   ['The Green Shed Underground',
#    'Basement level, 34 E Row Canberra ACT 2601 Australia',
#    None,
#    None,
#    'Tue - Fri 10:30am - 6pm',
#    'Sat 10:30am - 4pm'],
#   ['Hopeworks Seaford Op Shop',
#    '2/36 Hartnett Dr 3198 Seaford, Victoria',
#    -38.1132955,
#    145.1415596,
#    'Mon - Fri 9am-4pm',
#    'Sat 9am-3pm',
#    'Sun CLOSED'],
#   ['The Collective',
#    '270 Rossiter Road, Koo Wee Rup',
#    -38.1996897,
#    145.4903231,
#    'Mon - Tue 10am-4pm',
#    'Fri - Sun 10am-4pm'],
#   ['All Nations Christian Church Op Shop',
#    '170 Seacombe Rd, Seaview Downs',
#    -35.0292948,
#    138.5415819,
#    'Wed - Thu 10-4pm'],
#   ['Anglican Op Shop',
#    'Shop 1 100 - 106  Old Pacific Hwy, Oxenford 4210',
#    None,
#    None,
#    'Mon - Fri 8.30 - 4.30',
#    'Sat 8.30 -1',
#    'Sun Closed'],
#   ['Destiny Inc. Op Shop',
#    '6 jervois Street Albert park',
#    -34.8767365,
#    138.5267642,
#    'Tue - Fri 9:30-4:00'],
#   ['Beach End Op Shop Mornington',
#    '70 McLaren Place Mornington Victoria 3931 Australia',
#    None,
#    None,
#    'Mon - Fri 10am - 4pm',
#    'Sat 10am - 2pm',
#    'Sun CLOSED'],
#   ['Starting Point Op Shop',
#    '6 Prossers Forest Road, Ravenswood, Launceston, TAS, 7250',
#    -41.416195,
#    147.1792899,
#    'Mon - Thu 10am-2pm',
#    'Fri - Sun Closed'],
#   ['Red Cross Shop',
#    '165 City Walk, Canberra ACT 2600',
#    -35.2824764,
#    149.1337811,
#    'Mon - Thu 9:30am - 5:30pm',
#    'Fri 9:30am - 7pm',
#    'Sat 10am - 5pm',
#    'Sun 11am - 4pm'],
#   ['Up-OPPING@Limestone',
#    '82 Limestone Avenue, Ainslie',
#    -35.2689268,
#    149.1402988,
#    'Fri 10.00 a.m. Till 2.00 p.m.',
#    'Sat First Saturday in month 10.00 till 2p.m,'],
#   ['1-9 Woolley Street, Dickson ACT 2602',
#    'Mon - Wed 9:00 am - 5:00pm',
#    None,
#    None,
#    'Thu - Sat 9:00 am - 8:30pm',
#    'Sun 9:00 am - 4:00pm'],
#   ['Boolimba Crescent, Narrabundah ACT 2604',
#    'Mon - Tue 9.00 am - 5.00 pm',
#    None,
#    None,
#    'Wed - Fri 9:00 am - 5:00 pm',
#    'Sat 9.00 am - 3.00 pm'],
#   ['Calvary Chapel Opshop',
#    '48-60 Cooper Street, Chifley ACT',
#    None,
#    None,
#    'Sat 8:00 am - 1:00pm'],
#   ['Anglicare Retail Phillip',
#    '41-43 Colbee court Phillip',
#    -35.3523271,
#    149.0880339,
#    'Mon - Fri 10:00 - 4:30',
#    'Sat 10:00 - 2:00'],
#   ['Phillip Salvos Store',
#    '48 Botany Street, Phillip',
#    -35.3506089,
#    149.0880265,
#    'Mon - Fri 9am to 4.30pm',
#    'Sat 9am to 2.30pm'],
#   ['Red Cross Shop Woden',
#    '20 Bradley St, Woden ACT, 2606',
#    -35.3449557,
#    149.0875137,
#    'Mon - Fri 9:00 - 5:00',
#    'Sat 10:00 - 5:00',
#    'Sun Temp Closed - TBA'],
#   ['Vinnies Phillip',
#    '17 Colbee Court, Phillip ACT 2602',
#    -35.3523271,
#    149.0880339,
#    'Mon - Fri 9:00 am - 5:00pm',
#    'Sat 9:00 am - 4:00 pm'],
#   ['Vinnies Weston',
#    '2/14 brierly street weston',
#    -35.3426295,
#    149.0520485,
#    'Mon - Fri 9.00 am - 5.00 pm',
#    'Sat 9:00 am - 4:00 pm',
#    'Sun 10:00 am - 4:00 pm'],
#   ['Weston Salvos',
#    '14 - 20 Trennery St, Weston',
#    None,
#    None,
#    'Mon - Fri 9am to 5pm',
#    'Sat 9am - 3:30pm'],
#   ['Jamison Salvos',
#    '53 Bowman St',
#    -33.8673764,
#    151.1898338,
#    'Mon - Fri 9.00 to 4.30',
#    'Sat 9.00 to 2.30'],
#   ['Cnr Ross Smith Cres and McIntosh Street, Scullin',
#    'Mon - Fri 10.00 am to 4.30 pm',
#    None,
#    None,
#    'Sat 10.00 am to 1.00 pm'],
#   ["Barney's Boutique",
#    '10 Charnwood Place, Charnwood',
#    -35.2054497,
#    149.0347996,
#    'Wed - Fri 1:30pm-5:00pm',
#    'Sat 10:00-1:00pm'],
#   ['kippax fair hardwick crescent holt',
#    'Mon - Fri 9.00 am - 5.00 pm',
#    None,
#    None,
#    'Sat 9:00 am - 4:00 pm',
#    'Sun 9:00 am - 4:00pm'],
#   ['ReRuns',
#    '20 Cartwright St, Charnwood ACT 2615',
#    -35.2023112,
#    149.0278608,
#    'Mon closed',
#    'Tue - Fri 10-12 and 1-4pm',
#    'Sat - Sun closed'],
#   ['cnr Rae & Purdue Streets, Belconnen ACT 2617',
#    'Mon - Fri 9:00 am- 5:00 pm',
#    None,
#    None,
#    'Sat 9:00 am - 5:00 pm',
#    'Sun 9:00 am - 4:00 pm'],
#   ['Salvos Belconnen',
#    '38 Weedon Close Belconnen',
#    -35.2417839,
#    149.0630568,
#    'Mon - Fri 9-5',
#    'Sat 9-2:30',
#    'Sun closed'],
#   ['MS Plus Tuggeranong',
#    'Shop 31 The Homeworld Centre Tuggeranong 150-180 SOWARD WAY, Greenway',
#    None,
#    None,
#    'Mon - Fri 9:30am - 5:00pm',
#    'Sat 9:00am - 2:00pm'],
#   ['MS Plus  Shop - Tuggeranong',
#    'HomeWorld Centre 150-180 SOWARD WAY, Greenway',
#    None,
#    None,
#    'Mon - Fri 9:30am - 5pm',
#    'Sat 9am - 2pm'],
#   ['Tuggeranong Salvos',
#    'Shop 4, 5 Tuggeranong Square, Greenway',
#    None,
#    None,
#    'Mon - Fri 9.30am - 4.30pm',
#    'Sat 9.30am - 3.00pm'],
#   ['Cnr Pittman St & Athlon Dr., Greenway ACT 2905',
#    'Mon - Thu 9:00 am - 5:00pm',
#    None,
#    None,
#    'Fri 9:00 am - 6:30pm',
#    'Sat 9:00 am - 4:00 pm',
#    'Sun 10:00 am - 4:00 pm'],
#   ['Fusion Op Shop Kambah',
#    'Shop 2, 30-36 Primmer Cct, Kambah',
#    None,
#    None,
#    'Mon - Fri 10am-5pm',
#    'Sat 10am-1pm',
#    'Sun Closed'],
#   ['Garratt street op shop',
#    '23 Garratt street wanniassa',
#    -35.3931953,
#    149.0864365,
#    'Tue 9.30 am to 2.30  pm',
#    'Wed - Thu 9.30 am -2.30 pm',
#    'Fri 9.30 am - 2.30 pm'],
#   ['Mitchell Salvos',
#    '32 Hoskins St, Mitchell',
#    -35.2176371,
#    149.1374992,
#    'Mon - Fri 9:30am - 4.30pm',
#    'Sat 9:30am - 3pm'],
#   ['32 Hoskins Street, Mitchell ACT 2911',
#    'Mon - Fri 9:00 am - 5:00 pm',
#    None,
#    None,
#    'Sat 9:00 am - 4:00 pm'],
#   ['Vinnies Gungahlin',
#    'Shop 2 Bunnings Centre, Hibberson St, Gungahlin ACT 2912',
#    None,
#    None,
#    'Mon - Fri 9am - 5.00pm',
#    'Sat - Sun 9am - 4pm'],
#   ['Seawall Savers of SWFL',
#    '5789 Cape Harbour Dr Suite 201, Building 201, Cape Coral, FL 33914',
#    None,
#    None,
#    'Mon - Fri 8:00am-4:30pm'],
#   ['Salvation Army Family Store',
#    '148 Elizabeth Street, Sydney',
#    -33.8776592,
#    151.2098894,
#    'Mon - Tue Closed',
#    'Wed - Fri 10am- 330pm',
#    'Sat - Sun Closed'],
#   ['Salvos Surry Hills',
#    '339 Crown St Surry Hills',
#    -33.8825925,
#    151.214528,
#    'Mon - Sat 930am - 4pm',
#    'Sun Closed'],
#   ['Red Cross Op Shop',
#    '143 B Oxford St, Darlinghurst NSW 2010',
#    -33.8795351,
#    151.215567,
#    'Mon - Sat 9%u202Fam%u20135%u202Fpm',
#    'Sun 11%u202Fam%u20135%u202Fpm'],
#   ['Savers Thrift',
#    'Oxford Village, Shop 31 & 33 55/73 Oxford St, Surry Hills NSW 2010',
#    None,
#    None,
#    'Mon - Wed 10am-7pm',
#    'Thu 10am-9pm',
#    'Fri 10am-7pm',
#    'Sat 10am-6pm',
#    'Sun 10am-5pm'],
#   ['Noffs Op Shop',
#    '332 Crown St, Surry Hills NSW 2010',
#    -33.8878375,
#    151.2135294,
#    'Mon - Fri 10am till 5pm',
#    'Sat - Sun 12pm till 4pm'],
#   ['Vinnies Surry Hills',
#    '406 Elizabeth Street, Surry Hills NSW 2010',
#    -33.8800472,
#    151.2089896,
#    'Mon - Wed 9:30am - 6:30pm',
#    'Thu 9:30am - 7:30pm',
#    'Fri 9:30am - 6:30pm',
#    'Sat 10:00am - 6:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Wayside Op Shop Kings Cross',
#    '29 Hughes St, Kings Cross',
#    None,
#    None,
#    'Mon - Fri 9am-4pm',
#    'Sat 10am-2pm'],
#   ['Wayside Chapel Op Shop',
#    '29 Hughes Street, Potts Point NSW 2011',
#    -33.8716474,
#    151.2244348,
#    'Mon - Fri 9am-4pm',
#    'Sat 10am-2pm'],
#   ['Vinnies Mascot',
#    '1201 Botany Street, Mascot NSW 2020',
#    None,
#    None,
#    'Mon - Sat 9:30am - 5:30pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Vinnies Paddington',
#    '292 Oxford Street, Paddington NSW 2021',
#    -33.8828661,
#    151.2205723,
#    'Mon - Wed 9:30am - 6:00pm',
#    'Thu 9:30am - 8:00pm',
#    'Fri - Sat 9:30am - 6:00pm',
#    'Sun 10:00am - 5:00pm'],
#   ['Paddington Red Cross',
#    '390 Oxford Street Paddington NSW 2021',
#    -33.8828661,
#    151.2205723,
#    'Mon - Wed 10:00am-6:00pm',
#    'Thu 10:00am-8:00pm',
#    'Fri - Sat 10:00am-6:00pm',
#    'Sun 11:00am-5:00pm'],
#   ['20 Spring Street', 'M - F 10.00-5.45 Sat 10.00 - 2.45', None, None],
#   ['Vinnies Waverley',
#    '255 Bronte Road, Waverley NSW 2024',
#    -33.9023094,
#    151.2635374,
#    'Mon - Wed 9:00am - 5:30pm',
#    'Thu 9:00am - 7:30pm',
#    'Fri - Sat 9:00am - 5:30pm',
#    'Sun 10:00am - 5:00pm'],
#   ['Unit 21 / 54-56 Beach Road Bondi Beach, NSW 2026 Australia',
#    'Mon - Sun 24 hours',
#    None,
#    None],
#   ['Vinnies Bondi Beach',
#    '60 Hall Street, Bondi Beach NSW 2026',
#    -33.8897851,
#    151.2712542,
#    'Mon - Fri 9:30am - 6:00pm',
#    'Sat 9:00am - 6:00pm',
#    'Sun 10:00am - 5:00pm'],
#   ['Wayside Op Shop North Bondi',
#    '40-42 Warners Ave North Bondi',
#    -33.8840848,
#    151.2710656,
#    'Tue - Fri 9am-4pm',
#    'Sat 10am-2pm'],
#   ['Peter Pan Op Shop',
#    'Club Rose Bay, 1 Vickery Ave, Rose Bay',
#    None,
#    None,
#    'Wed 12pm to 8pm',
#    'Thu 12pm to 5.30pm',
#    'Fri 12pm to 3pm'],
#   ['Vinnies Randwick',
#    '27 Belmore Street, Randwick NSW 2031',
#    None,
#    None,
#    'Mon - Wed 9:00am - 5:30pm',
#    'Thu 9:00am - 7:00pm',
#    'Fri 9:00am - 5:30pm',
#    'Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 5:00pm'],
#   ['Noffs Op Shop Kingsford',
#    '2/46 Borrodale Rd, Kingsford NSW 2032',
#    -33.9234059,
#    151.2241424,
#    'Mon - Sun 10am to 4pm'],
#   ['Vinnies Kingsford',
#    '381 Anzac Parade, Kingsford NSW 2032',
#    -33.9259905,
#    151.2309269,
#    'Mon - Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Vinnies Maroubra',
#    '785 Anzac Parade, Maroubra NSW 2035',
#    -33.9496137,
#    151.2409787,
#    'Mon - Wed 9:00am - 5:30pm',
#    'Thu 9:00pm - 7:00pm',
#    'Fri 9:00am - 5:30pm',
#    'Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Hunt 4 Hope Op Shop',
#    '775 Anzac Parade  Maroubra NSW 2035',
#    -33.9362448,
#    151.2378487,
#    'Mon - Fri 9am - 5pm',
#    'Sat 9am - 3pm',
#    'Sun Closed'],
#   ['Anglicare',
#    '773 Anzac Parade, Maroubra NSW 2035',
#    -33.9496137,
#    151.2409787,
#    'Mon - Fri 9am%u20135pm',
#    'Sat 9am%u20132:45pm',
#    'Sun CLOSED'],
#   ['Noffs Op Shop Rozelle',
#    '704 Darling St, Rozelle NSW 2039',
#    -33.8594262,
#    151.1719554,
#    'Mon - Sun 10am till 5pm'],
#   ['Vinnies Leichhardt',
#    '121-123 Marion Street, Leichhardt NSW 2040',
#    -33.8839469,
#    151.1511284,
#    'Mon - Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Noffs Shop',
#    '461 King Street, Newtown',
#    -33.8974618,
#    151.1788578,
#    'Mon - Wed 11am till 4pm',
#    'Thu 11am till 8pm',
#    'Fri 11am till 4pm',
#    'Sat 10:30am till 5pm',
#    'Sun 10am till 4pm'],
#   ['Vinnies Newtown',
#    '187 King Street, Newtown NSW 2042',
#    -33.8952555,
#    151.1816796,
#    'Mon - Wed 9:30am - 6:00pm',
#    'Thu 9:30am - 8:00pm',
#    'Fri - Sat 9:30am - 6:00pm',
#    'Sun 10:00am - 5:00pm'],
#   ['85 Enmore Road',
#    'Mon - Wed 10 to 4',
#    None,
#    None,
#    'Thu 10 to 6',
#    'Fri - Sat 10 to 4',
#    'Sun 10 to 3'],
#   ['Newtown Red Cross Shop',
#    'Shop 2, 359 King Street, Newtown, 2042',
#    None,
#    None,
#    'Mon - Wed 11am - 7pm',
#    'Thu - Fri 11am - 9pm',
#    'Sat 11am - 7pm',
#    'Sun 11am - 5pm'],
#   ['Salvos Tempe',
#    '7 Bellevue Street, Tempe',
#    -33.9218186,
#    151.1683119,
#    'Mon - Fri 9am - 5:30pm',
#    'Sat 8:30am - 3:45pm'],
#   ['Vinnies North Sydney',
#    '6 Bay Road, North Sydney NSW 2060',
#    -33.8381182,
#    151.1963173,
#    'Mon - Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Salvation Army Family Store',
#    '161 Walker Street North Sydney',
#    -33.8373771,
#    151.209507,
#    'Mon - Thu 10 - 5:30',
#    'Fri 10 - 5',
#    'Sat 11 - 3:00',
#    'Sun CLOSED'],
#   ['Vinnies Crows Nest',
#    '60 Alexander Street, Crows Nest NSW 2065',
#    -33.8245967,
#    151.202632,
#    'Mon - Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Goodwill Op Shops',
#    '150 Longueville Road Lane Cove NSW',
#    -33.8124753,
#    151.1747114,
#    'Mon - Fri 9:30am to 5pm',
#    'Sat 9:30am to 4pm',
#    'Sun Closed'],
#   ['Vinnies Lane Cove',
#    '89 Longueville Road, Lane Cove NSW 2066',
#    -33.8124753,
#    151.1747114,
#    'Mon - Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Red Cross Lane Cove',
#    '99 Longueville Road',
#    -33.8124753,
#    151.1747114,
#    'Mon 10am-6pm',
#    'Tue - Sat 9:30am-5:30pm',
#    'Sun 10am-3pm'],
#   ['Online', '24 Hours', -33.9758194, 151.0201104],
#   ['Vinnies Gordon',
#    '756 Pacific Highway, Gordon NSW 2072',
#    -33.7555623,
#    151.1528071,
#    'Mon - Fri 9:30am-5:00pm',
#    'Sat 9:30am-1:30pm'],
#   ['Gordon Red Threads',
#    '781 Pacific Highway, Gordon, 2072',
#    -33.759231,
#    151.1539918,
#    'Mon - Sat 9am - 5pm'],
#   ['Salvation Army Family Store',
#    '755 Pacific Highway Gordon',
#    -33.75539,
#    151.153077,
#    'Mon - Fri 930-400',
#    'Sat 930-3',
#    'Sun closed'],
#   ['Pymble Red Cross',
#    '979 Pacific Highway\tPymble NSW 2173',
#    -33.7506855,
#    151.147019,
#    'Mon - Fri 10:00am - 4:00pm',
#    'Sat 10.00am - 12.00pm'],
#   ['Vinnies Turramurra',
#    'Shop 3 / 1392 Pacific Highway, Turramurra  NSW 2074',
#    None,
#    None,
#    'Mon - Fri 9.30AM-4.30PM',
#    'Sat 9.30AM-1.30PM'],
#   ['Vinnies St Ives',
#    '188 Mona Vale Road, St Ives NSW 2075',
#    -33.7261801,
#    151.1675069],
#   ['Lifeline Hornsby Pop-up Bookshop',
#    '20 George st, Hornsby',
#    -33.5489503,
#    151.2282114,
#    'Mon Closed',
#    'Tue - Sat 10am - 4pm',
#    'Sun Closed'],
#   ['Missions O Shop',
#    '393 Pacific Highway, Asquith',
#    -33.6878521,
#    151.1079378,
#    'Mon - Fri 9:30am - 5:00pm',
#    'Sat 9:30am - 1:00pm',
#    'Sun Closed'],
#   ['Salvos Hornsby Family Store',
#    '29-31 Burdett Street HORNSBY NSW 2077',
#    -33.7027642,
#    151.1025824,
#    'Mon - Fri 9am to 3pm',
#    'Sat 8:30am to 3:00pm'],
#   ['Vinnies Hornsby',
#    '41 Jersey St',
#    -33.6992164,
#    151.0983818,
#    'Mon - Sat 9am - 5pm',
#    'Sun 10am - 4pm'],
#   ['Fusion OpShop',
#    '1 Jersey St Hornsby',
#    -33.7016155,
#    151.0979596,
#    'Mon - Fri 10am-4pm',
#    'Sat 10am-12.30pm',
#    'Sun Closed'],
#   ['Brooklyn & Community Op Shop',
#    '10 Dangar Rd, Brooklyn',
#    -33.5472637,
#    151.2267915,
#    'Wed- Fri:  10.30- 3.30,  Sat & Sun: 10.30- 2.30'],
#   ['Lifeline Forestville',
#    '49 The Centre  Forestville NSW 2087',
#    -33.7619587,
#    151.2152678,
#    'Mon - Sat 9am-4pm',
#    'Sun Closed'],
#   ['Vinnies Forestville',
#    '24 The Centre, Forestville NSW 2087',
#    -33.7619587,
#    151.2152678,
#    'Mon - Sat 9AM-5PM',
#    'Sun Closed'],
#   ['Vinnies Mosman',
#    '10 Spit Road, Mosman NSW 2088',
#    -33.8242501,
#    151.2408146,
#    'Mon - Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Lifeline Shop Spit Junction',
#    '20 Spit road',
#    -33.8137787,
#    151.2439972,
#    'Mon - Sat 10am-4pm',
#    'Sun 10am-3pm'],
#   ['Salvos Neutral Bay Family Store',
#    'Shop 5, 27 Grosvenor Street NEUTRAL BAY NSW 2089',
#    None,
#    None,
#    'Mon - Sat 9:00 AM - 5:30 PM',
#    'Sun Closed'],
#   ['Lifeline Cremorne',
#    '112 Cabramatta Road Cremorne',
#    -33.8289238,
#    151.2292718,
#    'Tue - Sat 10am-5pm'],
#   ['Lifeline Shop Balgowlah',
#    '120 Condamine Street',
#    -33.7834617,
#    151.267424,
#    'Mon - Sun 10am - 4pm'],
#   ['Balgowlah Salvos',
#    '54 Balgowlah Road, Balgowlah',
#    -33.7901638,
#    151.2653992,
#    'Mon - Fri 9am - 5pm',
#    'Sat 9am - 4pm'],
#   ['Lifeline Shop Online',
#    '310 Sydney Rd, Balgowlah NSW 2093',
#    -33.795483,
#    151.2551297],
#   ['Vinnies Balgowlah',
#    '393 Sydney Road, Balgowlah NSW 2093',
#    -33.7948222,
#    151.257061,
#    'Mon - Fri 9AM-5PM',
#    'Sat 9AM-2PM',
#    'Sun Closed'],
#   ['Lifeline Manly',
#    '46 Sydney Road Manly, NSW 2095',
#    -33.7968947,
#    151.2852374,
#    'Mon - Sun 10am-4pm'],
#   ['Op for Change',
#    'Shop 2, 199 Pittwater Rd, Manly',
#    None,
#    None,
#    'Wed - Sun 10am to 4pm'],
#   ['Manly Red Cross Shop',
#    '42 Belgrave Street, Manly 2095 NSW',
#    -33.7957518,
#    151.2854053,
#    'Mon - Sat 9-5',
#    'Sun 10-4'],
#   ['Vinnies Manly',
#    '2 - 10 Pittwater Road, Manly NSW 2095',
#    -33.7953542,
#    151.2853455,
#    'Mon - Fri 9AM-5PM',
#    'Sat 9AM-3PM',
#    'Sun Closed'],
#   ['Distribution center and Warehouse',
#    '267 Harbord Rd Brookvale',
#    -33.7633971,
#    151.2798723,
#    'Mon - Fri 9am-1pm'],
#   ['Lifeline Dee Why',
#    '908 Pittwater Rd, Dee Why, NSW, 2099',
#    -33.7580194,
#    151.281277,
#    'Tue - Sat 10am-4pm'],
#   ['Save The Children Op Shop Dee Why',
#    '683 Pittwater Rd Dee Why',
#    -33.7547741,
#    151.2838803,
#    'Mon - Sat 9am - 4.30pm',
#    'Sun 10am - 4pm'],
#   ['Goodwill Op Shop',
#    '545 Pittwater Road BROOKVALE NSW',
#    -33.7658876,
#    151.2696785,
#    'Mon - Sat 9am to 4:30pm',
#    'Sun Closed'],
#   ['Lifeline Shop Brookvale',
#    '18 Roger Street Brookvale',
#    -33.7645493,
#    151.2696269,
#    'Tue - Fri 11am - 4pm',
#    'Sat 10am - 3pm'],
#   ['Brookvale Salvos',
#    '11 Dale Street, BROOKVALE NSW 2100',
#    -33.7648114,
#    151.2687076],
#   ['Vinnies Narrabeen',
#    '1308 - 1310 Pittwater Road, Narrabeen NSW 2101',
#    -33.713916,
#    151.2974916,
#    'Mon - Fri 9AM-5PM',
#    'Sat 9AM-2PM',
#    'Sun Closed'],
#   ['Vinnies Mona Vale',
#    'Shop 8 Bungan Court  13 Waratah Street, Mona Vale NSW 2103',
#    None,
#    None,
#    'Mon - Wed 9AM-5PM',
#    'Thu 9AM-6PM',
#    'Fri 9AM-5PM',
#    'Sat 10AM-3PM',
#    'Sun Closed'],
#   ['Avalon Red Cross',
#    '5/48 Old Barrenjoey Road, Avalon, 2107',
#    -33.6361034,
#    151.3294842,
#    'Mon - Fri 9.30am-3pm',
#    'Sat 9.30am-12pm'],
#   ['Lifeline Avalon',
#    '683 Barrenjoey Road, Avalon Beach NSW 2107',
#    -33.6233639,
#    151.3336501,
#    'Mon - Fri 9am - 5pm',
#    'Sat 9.30am - 4pm'],
#   ['Gladesville Salvos',
#    '187 Victoria Road, GLADESVILLE  2111',
#    -33.8331538,
#    151.1274015],
#   ['24B Church Street, Ryde',
#    'Mon - Fri 9:30 am - 4 pm',
#    None,
#    None,
#    'Sat 9:00 am - 12 pm'],
#   ['Vinnies North Ryde',
#    "191-197 Cox's Road, North Ryde NSW 2113",
#    None,
#    None,
#    'Mon - Wed 9:00am - 5:00pm',
#    'Thu 9:00am - 6:00pm',
#    'Fri - Sat 9:00am - 5:00pm',
#    'Sun 11:00am - 5:00pm'],
#   ['Save The Children Op Shop West Ryde',
#    '2 F Ryedale Rd West Ryde NSW',
#    -33.8050676,
#    151.0914637,
#    'Mon - Sat 9am - 4.30pm',
#    'Sun 10am - 4pm'],
#   ['Vinnies West Ryde',
#    '47 Ryedale Road, West Ryde NSW 2114',
#    -33.807184,
#    151.0911874,
#    'Mon - Thu 9:00am - 5:00pm',
#    'Fri 9:00am - 7:00pm',
#    'Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Vinnies Pennant Hills',
#    '364 Pennant Hills Road, Pennant Hills NSW 2120',
#    -33.738966,
#    151.070365,
#    'Mon - Fri 9AM-4.00PM',
#    'Sat 9AM-12.30PM'],
#   ['8C Station St Thornleigh',
#    'Thu Thursday 10 am to 4 pm',
#    None,
#    None,
#    'Fri Friday 10 am to 4 pm',
#    'Sat Saturday 10 am to 4 pm'],
#   ['Westleigh Salvos',
#    'Shop 21 Westleigh Shopping Town Cnr Duffy Ave & Eucalyptus Drive, WESTLEIGH  2120',
#    None,
#    None,
#    'Mon - Wed 9:00am-4:30pm',
#    'Thu - Fri 9:00am-5:00pm',
#    'Sat 9:00am-2:00pm'],
#   ['Vinnies Epping',
#    '21 Oxford Street, Epping NSW 2121',
#    -33.7711926,
#    151.0826762,
#    'Mon - Fri 9am - 4:30pm',
#    'Sat 9am - 12pm'],
#   ['Vinnies Summer Hill',
#    '142 Smith Street, Summer Hill NSW 2130',
#    -33.8919241,
#    151.1374293,
#    'Mon - Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Ashfield Baptist Church OpShop',
#    '19 Holden St, Ashfield, NSW, 2131',
#    -33.8907967,
#    151.1252243,
#    'Fri 9am - 2pm'],
#   ['Salvos Store Lidcombe',
#    '4/82 Parramatta Rd, Lidcombe NSW 2141',
#    -33.8460125,
#    151.0439403,
#    'Mon - Fri 9-5',
#    'Sat 9-3'],
#   ['Vinnies Toongabbie',
#    '1 Cornelia Road, Toongabbie NSW 2146',
#    -33.7871033,
#    150.9491259,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9AM-12PM',
#    'Sun Closed'],
#   ['Rythms Opp Shop',
#    '154 Best Rd, Seven Hills, NSW, 2147',
#    -33.7771604,
#    150.9370464,
#    'Tue - Fri 9am - 4.30pm',
#    'Sat 9am - 12'],
#   ['Vinnies Blacktown',
#    'Shop C4, 14 St Martins Crescent , Blacktown NSW 2148',
#    None,
#    None,
#    'Mon - Fri 9AM-5PM',
#    'Sat 9AM-4PM',
#    'Sun 10AM-3PM'],
#   ['Gateway Services',
#    '67 Terrigal Street, Marayong, NSW 2148',
#    -33.7475201,
#    150.8857548,
#    'Mon - Fri 9am - 5pm'],
#   ['Save the Children - Blacktown',
#    '107 Main Street, Blacktown',
#    -33.7689409,
#    150.9076721,
#    'Mon - Fri 9am to 4:45pm',
#    'Sat 9am to 1:45pm'],
#   ['Marayong Salvos',
#    '171 Richmond Road, MARAYONG  2148',
#    -33.7549512,
#    150.8915863,
#    'Mon - Fri  8.30am - 4.30pm  Sat 8.30am - 1.45pm'],
#   ['Gateway Services',
#    '67 Terrigal St, Marayong, New South Wales 2148',
#    -33.7475201,
#    150.8857548,
#    'Mon - Sun 9:00 AM%u20135:00 PM'],
#   ['249 Church St Parramatta NSW 2150',
#    'Mon - Fri 10:00 am  - 4:00 pm',
#    None,
#    None,
#    'Sat 10:00 am  - 3:00 pm',
#    'Sun Closed'],
#   ['Vinnies Baulkham Hills',
#    '1 / 20 Old Northern Road, Baulkham Hills NSW 2153',
#    -33.7552541,
#    150.9930673,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9AM-1PM',
#    'Sun Closed'],
#   ['Lifeline Shop Castle Hill',
#    'Level 2, Shop 302, Castle Towers Shopping Centre 6-14 Castle Street, Castle HIll',
#    None,
#    None,
#    'Mon - Fri 9am - 4.45pm',
#    'Sat 9am - 4pm',
#    'Sun Closed'],
#   ['Vinnies Castle Hill',
#    '5 / 261 Old Northern Road, Castle Hill NSW 2154',
#    -33.7315266,
#    151.0090223,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9AM-12PM',
#    'Sun Closed'],
#   ['Vinnies Dural',
#    'Shop 9 Round Corner Shopping Centre Kenthurst Road, Dural NSW 2158',
#    None,
#    None,
#    'Mon - Fri 9AM-5PM',
#    'Sat 9AM-2PM',
#    'Sun Closed'],
#   ["Salvo's Dural Store",
#    '15/829 Old Northern Rd, Dural, NSW',
#    -33.68219,
#    151.028096,
#    'Mon - Fri 9am-4pm',
#    'Sat 9am-12:30pm'],
#   ['Guildford Red Cross',
#    '294 Railway Terrace, Guildford, 2161',
#    -33.8510626,
#    150.987072,
#    'Thu - Fri 9am-12pm',
#    'Sat last of month  9am-12pm'],
#   ['Chester Hill Salvos',
#    '159 Priam Street, CHESTER HILL  2162',
#    -33.8753302,
#    151.0036826,
#    'Mon - Fri 9.00am - 4.30pm',
#    'Sat 9.00am - 2.30pm',
#    'Sun Closed'],
#   ['The Anglicare Shops Factory Outlet',
#    '9 Christina Rd Villawood NSW 2163',
#    -33.8811365,
#    150.9860176,
#    'Mon - Fri 9.00 - 4.00',
#    'Sat 9.00 - 1.45'],
#   ['Smithfield, Sydney, NSW, 2164', 'Mon - Sun 12am - 12 am', None, None],
#   ['Greystanes Uniting Church  Op Shop',
#    '37 Dell St Woodpark',
#    -33.8412261,
#    150.9615909,
#    'Mon - Fri 9.30am-3.30pm',
#    'Sat 9.00am -12 noon'],
#   ['Vinnies Fairfield',
#    '101-103 Ware Street, Fairfield NSW 2165',
#    -33.8660764,
#    150.9511259,
#    'Mon - Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Save the Children - Fairfield',
#    '97 The Crescent, Fairfield',
#    -33.8716761,
#    150.9572489,
#    'Mon - Fri 9.00am to 4.45pm',
#    'Sat 10.00am to 1.00pm'],
#   ['Vinnies Fairfield Heights',
#    'Shop 1/243 The Boulevarde, Fairfield Heights NSW 2165',
#    None,
#    None,
#    'Mon - Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Fairfield Salvos',
#    '8-10 Hamilton Road, FAIRFIELD  2165',
#    -33.8717219,
#    150.9345513,
#    'Mon - Fri 8:30 am - 4:30 pm',
#    'Sat 9am - 3pm'],
#   ['Vinnies Miller',
#    'Shop 42-43 Miller Community Shopping Centre 90 Cartwright Ave, Miller NSW 2168',
#    None,
#    None,
#    'Mon - Wed 9:00am - 5:00pm',
#    'Thu - Fri 9:00am - 6:00pm',
#    'Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Lifeline Liverpool',
#    '66 Macquarie St',
#    -33.8592019,
#    151.2134461,
#    'Mon - Fri 9am - 4.45pm',
#    'Sat 9am - 3pm',
#    'Sun Closed'],
#   ['Save the Children - Liverpool',
#    '265 George Street, Liverpool',
#    -33.9201071,
#    150.9253852,
#    'Mon - Fri 9.00am to 4.45pm',
#    'Sat 9.00am to 12.00pm'],
#   ['Mission Australia Op-Shop',
#    '28 Railway Street, Liverpool',
#    -33.9242981,
#    150.9259391,
#    'Mon - Fri 9.00 to 4.30',
#    'Sat 10.00 to 2.00'],
#   ['Vinnies Mt Pritchard',
#    '248 Humphries Road, Bonnyrigg NSW 2177',
#    -33.8926714,
#    150.8986711,
#    'Mon - Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['iCare Community OpShop',
#    '1/1640 Camden Valley Way, Leppington',
#    -33.964161,
#    150.817011,
#    'Mon Monday 9am - 5pm',
#    'Tue Tuesday 9am - 5pm',
#    'Wed Wednesday 9am - 5pm',
#    'Thu Thursday 9am - 5pm',
#    'Fri Friday 9am - 5pm',
#    'Sat Saturday 9am - 3pm'],
#   ['Red Cross Belmore',
#    '1 Bridge Rd, Belmore, 2192',
#    -33.917988,
#    151.0858998,
#    'Mon - Sat 9:00am-1:30pm'],
#   ['Save the Children - Campsie',
#    '323 Beamish Street, Campsie',
#    -33.9138827,
#    151.104268,
#    'Mon - Fri 9am to 4:45pm',
#    'Sat 9am to 1:45pm'],
#   ['Oppshoppers Australia',
#    '2/281-287 Beamish St Campsie',
#    None,
#    None,
#    'Mon - Sat 9am-5pm'],
#   ['Salvos Yagoona',
#    '550 Hume Highway, YAGOONA NSW 2199',
#    -33.9068267,
#    151.0231387,
#    'Mon - Fri 8.30am to 4.30pm',
#    'Sat 9am to 3pm',
#    'Sun Closed.'],
#   ['Op Shop Sydney',
#    '359 Old Canterbury Rd, Dulwich Hill NSW 2203',
#    -33.9029325,
#    151.1301655,
#    'Mon - Fri 9am - 5pm'],
#   ['The PM OP Shop',
#    '357-359 old canterbury road, dulwich hill',
#    -33.9029325,
#    151.1301655,
#    'Mon - Fri 9am - 3pm',
#    'Sat 9am - 4pm',
#    'Sun Closed'],
#   ['Vinnies Dulwich Hill',
#    '528 Marrickville Road, Dulwich Hill NSW 2203',
#    -33.9034651,
#    151.1425193,
#    'Mon - Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Save the Children- Marrickville',
#    '147 Marrickville Road, Marrickville',
#    -33.9111164,
#    151.1576058,
#    'Mon - Fri 9.00am to 4.45pm',
#    'Sat 9.00am to 1.45pm'],
#   ['Reverse Garbage',
#    '30 Carrington Road, Marrickville',
#    -33.9200608,
#    151.1553286,
#    'Mon - Sat 9 to 5',
#    'Sun 9 to 4'],
#   ['Anglicare Shop',
#    '171 Marrickville Rd Marickville',
#    None,
#    None,
#    'Mon - Fri 9.00-4.45',
#    'Sat 9.00-1.30',
#    'Sun closed'],
#   ['Noffs Op Shop Marrickville',
#    '290 Marrickville Road',
#    -33.9070505,
#    151.1470946,
#    'Mon - Sat 10am to 5pm',
#    'Sun 10am to 4pm'],
#   ['Marrickville Salvos',
#    '207 Marrickville Road, MARRICKVILLE  2204',
#    -33.9070505,
#    151.1470946],
#   ['Narwee Family Store',
#    '6/3 Hurst Place NARWEE NSW 2209',
#    -33.9481852,
#    151.07057,
#    'Mon - Fri 9:30am - 4:00pm',
#    'Sat 10:00am - 1:00pm',
#    'Sun Closed'],
#   ['Riverwood Salvos',
#    '299 Belmore Road, RIVERWOOD  2210',
#    -33.9529134,
#    151.0518278],
#   ['13 Howard Road Padstow 2211',
#    'Mon - Fri 9 to 4',
#    None,
#    None,
#    'Sat 9 to 12.30pm'],
#   ['Renew Community store',
#    '23 Cahors rd Padstow',
#    -33.9513632,
#    151.0322337,
#    'Mon 9:30am-4:30pm',
#    'Wed - Fri 9:30am-4:30pm',
#    'Sat 9:30am-12pm'],
#   ['Vinnies Revesby',
#    '14 Selems Parade, Revesby NSW 2212',
#    -33.9510112,
#    151.0148992,
#    'Mon - Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Salvos Panania Family Store',
#    '136 Tower Street PANANIA NSW 2213',
#    -33.955726,
#    150.9949161,
#    'Mon - Sat 9am - 4:30pm'],
#   ['Anglicare Store', '463 Prince Highway Rockdale', None, None],
#   ['Noffs Op Shop Rockdale',
#    '464 Princes Hwy Rockdale',
#    -33.9516931,
#    151.1382388,
#    'Mon - Sun 10am till 5pm'],
#   ['Save the Children - Rockdale',
#    '4A/452 Princes Highway, Rockdale',
#    None,
#    None,
#    'Mon - Fri 9.00am to 4.45pm',
#    'Sat 9.00am to 1.45pm'],
#   ['Vinnies Rockdale',
#    '445 Princes Highway, Rockdale NSW 2216',
#    -33.9497489,
#    151.1391593,
#    'Mon - Sat 9:00am - 5:00pm',
#    'Sun 10:00am - 4:00pm'],
#   ['Save the Children - Hurstville',
#    'Shop 1/243 Forest Road, Hurstville',
#    None,
#    None,
#    'Mon - Fri 9.00am to 4.45pm',
#    'Sat 9.00am to 1.45pm'],
#   ['Uniting Church Op Shop',
#    '4/60 Penshurst St Penshurst 2222',
#    -33.9579724,
#    151.0819069,
#    'Mon - Fri 9.00 - 3.30',
#    'Sat 9.30 - 1.00'],
#   ['Mortdale Uniting Church Op store', '18 morts street mortdale', None, None],
#   ['Vinnies Mortdale',
#    '15 Cook Street, Mortdale NSW 2223',
#    -33.969354,
#    151.0818484,
#    'Mon - Sat 9:00am - 4:30pm',
#    'Sun 10:00am - 4:00pm'],
#   ['SeeChange Op Shop',
#    '40 Railway Cres, Jannali, NSW, 2226',
#    -34.0151022,
#    151.0650477,
#    'Mon - Fri 9:30am - 3:00pm',
#    'Sat - Sun Closed'],
#   ['Jannali Red Cross',
#    '2 Jannali Avenue, Jannali, 2226',
#    -34.0225172,
#    151.0633194,
#    'Mon 10am-2pm',
#    'Wed - Fri 10am-2pm'],
#   ['Vinnies Caringbah',
#    '20 President Avenue, Caringbah NSW 2229',
#    -34.0425214,
#    151.1188326,
#    'Mon - Fri 9:00am - 5:00pm',
#    'Sat 10:00am - 5:00pm',
#    'Sun 11:00am - 4:00pm'],
#   ['Retail Therapy',
#    '29-33 President Avenue',
#    -34.0381715,
#    151.0873227,
#    'Mon - Fri 10am - 4:30pm',
#    'Sat 9am - 12pm'],
#   ['Vinnies Cronulla',
#    '130 Cronulla Street, Cronulla NSW 2230',
#    -34.05535,
#    151.1518774,
#    'Mon - Sun 9:00am - 5:00pm'],
#   ['Shire Thrift',
#    'Shop 1 / 49 Eton Sutherland',
#    None,
#    None,
#    'Mon - Sat 10am-4pm',
#    'Sun 10am-2pm'],
#   ["Millie's Opportunity Shop",
#    '5/16 Boyle St, Sutherland',
#    -34.0327793,
#    151.0578388,
#    'Mon - Fri 9am - 5pm',
#    'Sat 9:30 - 2pm',
#    'Sun Closed'],
#   ['Sutherland Salvos',
#    '573 President Avenue, SUTHERLAND  2232',
#    -34.0334151,
#    151.0574179],
#   ['Menai Salvos',
#    '5/778 Old Illawarra Road, MENAI  2234',
#    -34.0235239,
#    151.0081389],
#   ['Lifeline Shop Gosford',
#    '136 Mann Street Gosford NSW 2250',
#    -33.4237296,
#    151.3425097,
#    'Mon - Fri 9am to 5pm',
#    'Sat 9am to 1pm',
#    'Sun Closed'],
#   ['Lifeline Shop East Gosford',
#    '52 York Street East Gosford',
#    -33.436264,
#    151.348832,
#    'Mon - Fri 9am to 5pm',
#    'Sat 9am to 4pm',
#    'Sun Closed'],
#   ['Vinnies East Gosford',
#    '81 Victoria Street, East Gosford NSW 2250',
#    -33.4394231,
#    151.354979,
#    'Mon - Sat 9AM-4PM',
#    'Sun Closed'],
#   ['Gosford Red Cross',
#    '1/156 Mann Street, Gosford, 2250',
#    -33.4237296,
#    151.3425097,
#    'Mon - Fri 930am - 5pm',
#    'Sat 930am - 1pm',
#    'Sun Closed'],
#   ['3 Watt Street, Gosford NSW 2250, and Shop T54 Deepwater Shopping Plaza, Woy Woy NSW 2256',
#    'Mon - Tue 11:00 am - 6:00 pm',
#    None,
#    None,
#    'Wed - Sat 11:00 am - 6:00 pm',
#    'Sun 11:00 am - 6:00 pm'],
#   ['Vinnies Lisarow',
#    'Lisarow Plaza, Shop14, 1 Parsons Road, Lisarow, NSW 2250',
#    None,
#    None,
#    'Mon - Sat 9am to 4pm',
#    'Sun 10am to 4pm'],
#   ['Gosford Salvos',
#    '348 Mann Street, GOSFORD NSW 2250',
#    -33.4223632,
#    151.3427836,
#    'Mon - Sat 9am-5pm',
#    'Sun Closed'],
#   ['Vinnies Kincumber',
#    'Shop 3 & 4 Kincumber Shopping Centre  39 Avoca Drive, Kincumber NSW 2251',
#    None,
#    None,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9AM-12PM'],
#   ['Cheeky Threads',
#    '165 Blackwall rd Woy Woy',
#    -33.4880341,
#    151.3257044,
#    'Mon - Fri 9-3',
#    'Sat 9-2'],
#   ['Woy Woy Salvos',
#    '74 Rawson Road, WOY WOY  2256',
#    -33.4926351,
#    151.3139846,
#    'Mon - Sat 9am to 5pm',
#    'Sun Closed'],
#   ['The Cottage Op Shop',
#    '151 Blackwall Rd, Woy Woy',
#    -33.4880341,
#    151.3257044,
#    'Mon - Fri 9am-4pm',
#    'Sat 9am-2pm',
#    'Sun Closed'],
#   ['Finders Keepers 17',
#    '1/287 Ocean View Rd, Ettalong NSW 2250',
#    -33.5135981,
#    151.3346056,
#    'Mon - Fri 9am-330pm',
#    'Sat 10am-2pm',
#    'Sun Closed'],
#   ['Salvation Army Umina Beach',
#    '9 Sydney Ave, Umina Beach NSW 2257',
#    -33.5214215,
#    151.3155281,
#    'Mon 10am - 1pm',
#    'Tue Closed',
#    'Wed 9am - 2pm',
#    'Thu - Sat Closed',
#    'Sun Closed'],
#   ['Vinnies Umina',
#    '344 West Street, Umina NSW 2257',
#    -33.5214513,
#    151.3176068,
#    'Mon - Sat 9AM-4PM',
#    'Sun 10AM-4PM'],
#   ['Youth Life Op Shop',
#    '291 West Street, Umina',
#    -33.5213296,
#    151.319271,
#    'Mon 1230pm-430pm',
#    'Tue - Fri 930am-430pm',
#    'Sat 930am-1230pm',
#    'Sun Closed'],
#   ['Tuggerah Salvos',
#    '130 Pacific Highway, TUGGERAH NSW 2259',
#    -33.3027175,
#    151.4202376,
#    'Mon - Sat 9am to 5pm',
#    'Sun Closed'],
#   ['Vinnies Erina Heights',
#    '3/490 Central Coast Highway, Erina Heights',
#    -33.4267137,
#    151.3969759,
#    'Mon - Sat 9am to 4pm',
#    'Sun Closed'],
#   ['Holy Trinity Op Shop',
#    '92 Serpentine Road, Terrigal, 2260',
#    -33.4371333,
#    151.4159384,
#    'Mon Closed',
#    'Tue - Thu 9am - 4pm',
#    'Fri 9am - 4pm - closed between 1015am - 1115am',
#    'Sat 10am - 1pm',
#    'Sun Closed'],
#   ['Save the Children Op Shop',
#    '8 Community Road, Bateau Bay',
#    -33.3719719,
#    151.4738645,
#    'Mon - Fri 9am to 4:45pm',
#    'Sat 9am to 3pm',
#    'Sun 10am to 2pm'],
#   ['Bateau Bay Anglican Op Shop',
#    '2 Tyrrell Place, Killarney Vale NSW 2261',
#    -33.3768802,
#    151.4651168,
#    'Mon 930am to 3pm',
#    'Tue Closed',
#    'Wed - Thu 930am to 3pm',
#    'Fri Closed',
#    'Sat Cosed',
#    'Sun Closed'],
#   ['The Hub Op Shop',
#    '2-6 Warrigal St The Entrance',
#    -33.3468397,
#    151.4952577,
#    'Mon Closed',
#    'Tue - Fri 9am to 330pm',
#    'Sat - Sun 9am to 2pm'],
#   ['The Entrance Red Cross',
#    '165 The Entrance Rd, The Entrance NSW 2261',
#    -33.338224,
#    151.4969605,
#    'Mon - Sat 9.30am - 4pm',
#    'Sun 10:00am - 3:00pm'],
#   ['Salvos The Entrance Family Store',
#    '191 The Entrance Road The Entrance NSW 2261',
#    -33.338224,
#    151.4969605,
#    'Mon - Fri 9am to 4pm',
#    'Sat 9am to 12pm'],
#   ['The Anglican Church Op Shop',
#    '24 Fairview Ave The Entrance',
#    -33.3422015,
#    151.4932975,
#    'Mon - Fri 9am to 3pm',
#    'Sat 9am to 12pm'],
#   ['Opportunity Knocks',
#    'Shop 4 43-45 Liamena Ave, San Remo, NSW, 2262',
#    None,
#    None,
#    'Mon - Fri Open',
#    'Sat 1st Saturday of the Month',
#    'Sun Closed'],
#   ['Toukley Neighourhood Centre Op Shop',
#    '1 Ron Alt Lane, Toukley, NSW 2263',
#    -33.2642268,
#    151.5398726,
#    'Mon - Fri 930am-330pm',
#    'Sat - Sun Closed'],
#   ['Salvos Toukley',
#    '28 Canton Beach Road TOUKLEY NSW 2263',
#    -33.2667869,
#    151.5404594,
#    'Mon - Sat 9am to 530pm',
#    'Sun Closed'],
#   ['Vinnies Toukley',
#    '173 Main Road, Toukley NSW 2263',
#    -33.263309,
#    151.5363618,
#    'Mon - Sat 9AM-4PM',
#    'Sun Closed'],
#   ['Salvos Bonnells Bay',
#    '330 Fishery Point Road BONNELLS BAY NSW 2264',
#    -33.1109947,
#    151.5320181,
#    'Mon - Fri 9-4'],
#   ['Morisset ADRA Op Shop',
#    '19 Gateway Blvd, Morisset, NSW 2264',
#    -33.1175744,
#    151.4724497,
#    'Mon - Wed 9am-3pm',
#    'Thu - Sat Closed',
#    'Sun 8am-2pm'],
#   ['Vinnies Morisset',
#    '75 Dora Street (next To Westpac Bank) , Morisset NSW 2264',
#    None,
#    None,
#    'Mon - Fri 9AM-3.30PM',
#    'Sat',
#    'Sun Closed'],
#   ['Borne Again Boutique',
#    '33 Newcastle Street, morisset nsw 2264',
#    -33.1078881,
#    151.4841796,
#    'Tue - Wed 9.15 am - 12.45 pm',
#    'Fri 9.15 am - 12.45 pm'],
#   ['Belmont North Salvos',
#    '3-356 Pacific Highway',
#    -30.3482833,
#    153.0656385,
#    'Mon-Fri 9am-5.30pm Sat 9am-4pm'],
#   ['Vinnies Belmont',
#    '21 Ernest Street, Belmont NSW 2280',
#    -33.0343236,
#    151.6620032,
#    'Mon - Fri 8.30AM-3PM',
#    'Sat 9AM-12PM',
#    'Sun Closed'],
#   ['Belmont Op Shop',
#    'Shop 7/8 600 Pacific Highway Belmont 2280 NSW',
#    None,
#    None,
#    'Mon - Fri 9am - 4 pm',
#    'Sat 9am - noon'],
#   ['Lifeline Belmont',
#    '550 Pacific Hwy, Belmont NSW 2280',
#    -33.0264844,
#    151.6617262],
#   ['Allira House Op Shop Warners Bay',
#    '22 John Street, Warners Bay NSW 2282',
#    -32.9720254,
#    151.6440783,
#    'Mon - Fri  9am - 4pm'],
#   ['Salvos Warners Bay',
#    '2/10-16 medcalf St, Warners Bay NSW',
#    -32.966078,
#    151.6436108,
#    'Mon - Sat 9am - 5pm',
#    'Sun Closed'],
#   ['Church 4 Life Warners Bay',
#    '250 Macquarie Rd, Warners Bay',
#    -32.9646202,
#    151.6537035,
#    'Mon - Fri 9am - 5pm',
#    'Sat 9am - 3pm'],
#   ['Save the Children - Toronto',
#    '49 The Boulevard, Toronto',
#    None,
#    None,
#    'Mon - Fri 9.00am to 4.45pm',
#    'Sat 9.00am to 12.15pm'],
#   ['Salvos Westlakes Family Store',
#    '67-73 The Boulevarde, TORONTO NSW 2283',
#    -33.0136152,
#    151.5956053],
#   ['Vinnies Toronto',
#    '80 The Boulevarde, Toronto NSW 2283',
#    -33.0125494,
#    151.5881855,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9AM-12PM',
#    'Sun Closed'],
#   ['Boolaroo Salvos',
#    '10/24 Main Street, BOOLAROO  2284',
#    None,
#    None,
#    'Mon-Fri 9.am-5pm Sat. 9am-4pm'],
#   ['Samaritans', '15 Main Road Boolaroo', -32.9457991, 151.6234767],
#   ['Cnr Kelton & Main Rd', 'Mon - Fri 10:00 to 4:00', None, None],
#   ['Lifeline Cardiff',
#    '288 Main Road Cardiff',
#    -32.9398071,
#    151.6597699,
#    'Mon - Fri 9am - 5pm',
#    'Sat 9am - 4pm'],
#   ['Church 4 Life Cardiff',
#    '5/343 Main Rd, Cardiff NSW 2285',
#    -32.9330052,
#    151.6541797,
#    'Mon - Fri 9am - 5pm',
#    'Sat 9am - 3pm'],
#   ['Op Shop Heaven', '298 Main Rd', -42.8346281, 147.2832636],
#   ['Lifeline Shop Wallsend',
#    '129 Nelson Street Wallsend NSW',
#    -32.8978865,
#    151.663566,
#    'Mon - Fri 9am - 4.30pm',
#    'Sat 9am - 1.30pm'],
#   ['Samaritans Wallsend',
#    '145 Nelson Street, Wallsend',
#    -32.8978865,
#    151.663566,
#    'Mon - Fri 9:30am - 4:30pm',
#    'Sat 9:30am - 12:30pm'],
#   ['Vinnies Wallsend',
#    '175 Nelson Street, Wallsend NSW 2287',
#    -32.8978865,
#    151.663566,
#    'Mon - Fri 8.30AM-3.30PM',
#    'Sat 9AM-12PM',
#    'Sun Closed'],
#   ['Second Edition', '145 Nelson Street, Wallsend', -32.8978865, 151.663566],
#   ['Jesmond Salvos',
#    '119 Newcastle Road, WALLSEND NSW 2287',
#    -32.9034644,
#    151.6802618,
#    'Mon - Sat 9am - 5pm'],
#   ['Charlestown Salvos',
#    'Shop 2, 219 Pacific Highway',
#    None,
#    None,
#    'Mon-Fri 9am-5pm',
#    'Sat 9am-3pm'],
#   ['Allira House Op Shop Mt Hutton',
#    '9 Wilsons Road, Mount Hutton, NSW 2290',
#    -32.9846859,
#    151.6709916,
#    'Mon - Fri 9am - 4pm',
#    'Sat - Sun CLOSED'],
#   ['Eastlakes Distribution Centre',
#    '91 Cadaga Road, Gateshead NSW 2290',
#    -32.9749533,
#    151.6847183,
#    'Mon - Fri 9AM-3PM',
#    'Sat - Sun Closed'],
#   ['Merewether Red Cross',
#    'Lindgard Private Hospital, 23 Merewether St, Merewether, 2291',
#    None,
#    None],
#   ['Red Cross Store at The Junction',
#    '2/200 Union St, The Junction, 2291',
#    -32.9390724,
#    151.7582168,
#    'Mon-Fri 9am-5pm, Sat 10am-4pm, Sun 10am-3pm'],
#   ['Lifeline Shop Hamilton North',
#    '1/54 Clyde St Hamilton North',
#    -32.9122034,
#    151.7364198,
#    'Mon - Fri 9am-5pm',
#    'Sat - Sun 10am-3pm'],
#   ['Secondary',
#    '8/54 clyde st Hamilton North Nsw',
#    -32.9122034,
#    151.7364198,
#    'Mon - Sat 10am - 4pm',
#    'Sun 10 am - 3pm'],
#   ['Cnr Beaumont St & Maitland Rd',
#    'Wed - Fri 10:00 to 5:00',
#    None,
#    None,
#    'Sat - Sun 10:00 to 4:00'],
#   ['mission markets', '48 Fern st Islington', -32.9138516, 151.7441672],
#   ['Vinnies Islington',
#    '125 Maitland Road, Islington NSW 2296',
#    -32.9202504,
#    151.752003,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9AM-12PM',
#    'Sun Closed'],
#   ['Vinnies Hamilton',
#    '143 Beaumont Street, Hamilton NSW 2303',
#    -32.9184029,
#    151.7480472,
#    'Mon - Fri 9AM-3PM',
#    'Sat 9AM-12PM',
#    'Sun Closed'],
#   ['Country Life Op Shop', '1 Donald St', -33.797919, 151.134371],
#   ['Samaritans Hamilton',
#    '19 Beaumont Street, Hamilton',
#    -32.9277981,
#    151.7461055,
#    'Mon - Fri 9:30am - 4:30pm',
#    'Sat 9:30am - 12:30pm'],
#   ['Samaritans Mayfield',
#    '131 Maitland Road, Mayfield',
#    -32.9015203,
#    151.7421579,
#    'Mon - Fri 9:30am - 4:00pm',
#    'Sat 9:30am - 12:00pm'],
#   ['Vinnies Mayfield',
#    '4 Church Street, Mayfield NSW 2304',
#    -32.8994228,
#    151.7409052,
#    'Mon - Fri 9AM-3.45PM',
#    'Sat 9AM-1PM',
#    'Sun Closed'],
#   ['2nd Chance Op Shop',
#    '37 Nabiac St, Nabiac   NSW',
#    -32.102224,
#    152.3854341,
#    'Mon - Sat 9am to 12noon'],
#   ['Vinnies Anna Bay',
#    '137 Gan Gan Road, Anna Bay NSW 2316',
#    -32.7775267,
#    152.0845245,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9AM-12PM',
#    'Sun Closed'],
#   ['Salvos Store Port Stephens',
#    'Unit 2/165 Salamander Way, Salamander Bay NSW 2317',
#    None,
#    None,
#    'Mon - Fri 9am - 1pm'],
#   ['Salamander Bay Recycling',
#    '360 Soldiers Point Road, Salamander Bay NSW',
#    -32.7285053,
#    152.0806887,
#    'Mon - Sat 9am - 4pm',
#    'Sun 9am - 2:30pm'],
#   ['Church4Life Op Shop',
#    'Kooinda Centre, 61 President Wilson Walk Tanilba Bay NSW 2319',
#    None,
#    None,
#    'Mon Monday 9am-4pm',
#    'Tue Tuesday 9am-4pm',
#    'Wed Wednesday 9am-4pm',
#    'Thu Thursday 9am-4pm',
#    'Fri Friday 9am-4pm',
#    'Sat Saturday 9am-12pm'],
#   ['Vinnies Tanilba Bay',
#    '67 President Wilson Walk, Tanilba Bay NSW 2319',
#    -32.734689,
#    152.0019759,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9AM-12PM',
#    'Sun Closed'],
#   ['Junkyard Gypsies',
#    '337 High Street, Maitland 2320 NSW',
#    -32.7317617,
#    151.5543793,
#    'Wed - Fri 10am - 330pm',
#    'Sat 10am - 1pm'],
#   ['Presbyterian Opportunity Shop',
#    '501 High Street, Maitland',
#    -32.735951,
#    151.5596221],
#   ['Vinnies Maitland',
#    '196 High Street, Maitland NSW 2320',
#    -32.7397691,
#    151.5630265,
#    'Tue - Fri 10AM - 4PM'],
#   ['Maitland Bay Boutique Red Cross',
#    'Maitland Public Hospital, 550-560 High St, Maitland, 2320',
#    None,
#    None],
#   ['Maitland Red Cross',
#    '386 High Street, Maitland, 2320',
#    -32.7317617,
#    151.5543793,
#    'Mon - Fri 9am - 5pm',
#    'Sat 9am - 1pm'],
#   ['Op Shop Heaven', '318 High St', -37.7640988, 145.1197671],
#   ['Lifeline Shop Maitland',
#    '385 High St Maitland, NSW',
#    -32.7332266,
#    151.5569427,
#    'Mon - Fri 9am - 5pm',
#    'Sat 9am - 4pm'],
#   ['Salvos Maitland',
#    '439 high st Maitland',
#    -32.7397691,
#    151.5630265,
#    'Mon - Sat 9am-5pm'],
#   ['Vinnies Beresfield',
#    '11 Beresford Avenue, Beresfield NSW 2322',
#    -32.8007212,
#    151.6568135,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9AM-12PM'],
#   ['Vinnies East Maitland',
#    '99 High Street, East Maitland NSW 2323',
#    -32.7505368,
#    151.5909937,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9AM-12PM',
#    'Sun Closed'],
#   ['Greenhills Salvos',
#    'Shops 4-5 The Village, 4a Garnett Road',
#    None,
#    None,
#    'Mon - Sat 9am-5pm'],
#   ['Living H(OP)E Shop',
#    '1 Garnett Road East maitland',
#    -32.7604938,
#    151.5915236,
#    'Mon - Fri 9:30AM - 2:00PM'],
#   ['Vinnies Raymond Terrace',
#    '37 Port Stephens Street, Raymond Terrace NSW 2324',
#    -32.7645747,
#    151.7375489,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9AM-12PM',
#    'Sun Closed'],
#   ['Vinnies Cessnock',
#    '55 Vincent Street, Cessnock NSW 2325',
#    -32.8326256,
#    151.3567509,
#    'Mon - Fri 9AM - 4PM',
#    'Sat 9AM - 12PM',
#    'Sun Closed'],
#   ['The Vines Scarlet Thread Op Shop',
#    'lot 472 cessnock rd abermain',
#    -32.8108128,
#    151.4288953,
#    'Tue - Fri 10am-3pm',
#    'Sat 10am-1pm'],
#   ['Vinnies Kurri Kurri',
#    '127 Lang Street, Kurri Kurri NSW 2327',
#    -32.8198955,
#    151.4791332,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9.30AM-11.30AM',
#    'Sun Closed'],
#   ['Kurri Kurri Red Cross',
#    '188 Barton Street, Kurri Kurri, 2327',
#    -32.8199735,
#    151.479449,
#    'Mon - Fri 9am - 3pm',
#    'Sat 9am - 12pm'],
#   ['Vinnies Singleton',
#    '37-39 Macquarie St  (Cnr Bourke St), Singleton NSW 2330',
#    None,
#    None,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9AM-12PM',
#    'Sun Closed'],
#   ['Op Shop Singleton', '219 John St Singleton NSW', -32.5652921, 151.16712],
#   ['Father Riley op shop',
#    '251 John Street SINGLETON NSW',
#    -32.5652921,
#    151.16712,
#    'Mon - Fri 9:30am to 3:30pm',
#    'Sat 9:00am to 12:00pm'],
#   ['Lifeline Shop Muswellbrook',
#    '33-37 Bridge Street, Muswellbrook',
#    -32.2581389,
#    150.8897498,
#    'Mon - Fri 9am - 4.30pm',
#    'Sat 9am - 3pm'],
#   ['Vinnies Muswellbrook',
#    '174 Bridge Street, Muswellbrook NSW 2333',
#    -32.2581389,
#    150.8897498,
#    'Mon - Fri 9AM-4PM',
#    'Sat 9AM-12PM',
#    'Sun Closed'],
#   ['Doo Stop Op Shop',
#    '75 Maitland St Branxton NSW',
#    -32.6559733,
#    151.3532119,
#    'Mon - Fri 10am-3pm',
#    'Sat - Sun closed'],
#   ['Branxton Op Shop',
#    '45 Cessnock Road Branxton',
#    -32.6575694,
#    151.3533707,
#    'Mon  Closed',
#    'Tue 9am - 3pm',
#    'Wed  Closed',
#    'Thu 9am - 3pm',
#    'Fri  Closed',
#    'Sat  9am - 12pm',
#    'Sun Closed'],
#   ['Vinnies Murrurundi',
#    '38 Mayne Street, Murrurundi NSW 2338',
#    -31.7640145,
#    150.8353983,
#    'Mon - Fri 9.30AM-3PM',
#    'Sat 9.30-12.30PM',
#    'Sun Closed'],
#   ['St Johns op shop',
#    '102 Carthage St',
#    -31.0891408,
#    150.9347484,
#    'Mon - Wed 9-12.30pm'],
#   ['Uniting Church Op Shop',
#    '24 darling street north tamworth 2340',
#    -31.0846522,
#    150.9296669,
#    'Mon 1pm - 4pm',
#    'Tue - Fri 10am - 4pm',
#    'Sat 9am - 12pm',
#    'Sun Closed'],
#   ['Vinnies Sth Tamworth',
#    '70 Duri Road, Tamworth NSW 2340',
#    -31.0971229,
#    150.9085418,
#    'Mon - Fri 10AM-3PM',
#    'Sat - Sun Closed'],
#   ['Salvos Tamworth Family Store',
#    '186 Peel Street TAMWORTH NSW 2340',
#    -31.0925198,
#    150.9315297],
#   ['One of a Kind Tamworth',
#    '3 Hill Street Tamworth NSW 2340',
#    -31.0883268,
#    150.9436452],
#   ['Vinnies Tamworth',
#    '488 Peel Street, Tamworth NSW 2340',
#    -31.0925198,
#    150.9315297,
#    'Mon - Fri 10AM-3.30PM',
#    'Sat 9.30AM-12PM',
#    'Sun Closed'],
#   ['Vinnies Werris Creek',
#    '66 Single Street, Werris Creek NSW 2341',
#    -31.3504664,
#    150.6470381,
#    'Mon Closed',
#    'Tue 9am to 2pm',
#    'Wed 9am to 2pm',
#    'Thu 9am to 2pm',
#    'Fri - Sat Closed',
#    'Sun Closed'],
#   ['Salvos Manilla Family Store',
#    '95 Manilla Street MANILLA NSW 2346 PO Box 86 MANILLA NSW 2346',
#    None,
#    None],
#   ['Salvos Barraba Family Store',
#    '77 Queen Street BARRABA NSW 2347',
#    -30.3729584,
#    150.6116271],
#   ['Vinnies Barraba',
#    '118 Queen Street, Barraba NSW 2347',
#    -30.3835555,
#    150.6096023,
#    'Mon Closed',
#    'Tue - Fri 10AM-2PM',
#    'Sat - Sun Closed'],
#   ['Salvos Armidale Family Store',
#    '99 Ohio Street ARMIDALE NSW 2350',
#    -30.5116031,
#    151.6521088],
#   ['Vinnies Armidale',
#    '162 Rusden Street, Armidale NSW 2350',
#    -30.5141716,
#    151.6626016,
#    'Mon - Fri 10AM-2PM',
#    'Sat 9AM-12PM'],
#   ['Vinnies Walcha',
#    '68 Derby Street, Walcha NSW 2354',
#    -30.9914386,
#    151.5921274,
#    'Mon Closed',
#    'Tue - Fri 9.30AM-2.30PM',
#    'Sat - Sun Closed'],
#   ['ADRA Op Shop Coonabarabran',
#    '62 Dalgarno Street COONABARABRAN NSW 2357',
#    -31.2740449,
#    149.2752698,
#    'Tue - Fri 10am - 4pm'],
#   ['Vinnies Coonabarabran',
#    '49 Dalgarno Street, Coonabarabran NSW 2357',
#    -31.2740449,
#    149.2752698,
#    'Mon - Fri 9:30AM- 4PM',
#    'Sat 10AM - 12:30PM',
#    'Sun Closed'],
#   ['Vinnies Uralla',
#    '20 Hill Street, Uralla NSW 2358',
#    -30.6424885,
#    151.5019917,
#    'Mon - Fri 9AM-12PM',
#    'Sat 9.30AM-11.30AM',
#    'Sun Closed'],
#   ['Vinnies Inverell',
#    '31 Oliver Street, Inverell NSW 2380',
#    -29.773299,
#    151.114189,
#    'Mon - Fri 9AM-3PM',
#    'Sat 9AM-11AM',
#    'Sun Closed'],
#   ['Salvos Inverell Family Store',
#    '45 Otho Street INVERELL NSW 2360',
#    -29.777845,
#    151.1147915,
#    'Mon - Fri 9am - 3pm',
#    'Sat 9am - noon',
#    'Sun Closed'],
#   ['Vinnies Guyra',
#    '153 Bradley Street, Guyra NSW 2365',
#    -30.2240712,
#    151.6710774,
#    'Mon Closed',
#    'Tue - Thu 10AM-2PM',
#    'Fri - Sun Closed'],
#   ['Vinnies Glen Innes',
#    '192 Bourke Street, Glen Innes NSW 2370',
#    -29.7391335,
#    151.7369115,
#    'Mon - Fri 10AM-3.30PM',
#    'Sat - Sun Closed'],
#   ['Vinnies Tenterfield',
#    '119 High Street, Tenterfield NSW 2372',
#    -29.0538622,
#    152.0196296,
#    'Mon 1PM-4PM',
#    'Tue - Fri 10AM-4PM',
#    'Sat - Sun Closed'],
#   ['Bowerbird Shop',
#    '418 quia road gunnedah',
#    -30.9586891,
#    150.2123783,
#    'Mon - Thu 8am to 3.45pm',
#    'Fri 8am to 2.45pm',
#    'Sat 9am to 11am'],
#   ['One of a Kind Gunnedah',
#    '72 Barber street Gunnedah NSW',
#    -30.9780582,
#    150.2495103,
#    'Mon - Fri 9am to 4pm',
#    'Sat 9am to 12pm',
#    'Sun Closed'],
#   ['Vinnies Gunnedah',
#    '146 Marquis Street, Gunnedah NSW 2380',
#    -30.9745598,
#    150.2551103,
#    'Tue - Fri 9AM-2.30PM'],
#   ['Vinnies Narrabri',
#    '102 Barwon Street, Narrabri NSW 2390',
#    None,
#    None,
#    'Mon - Fri 10AM-2PM',
#    'Sat 9AM-11AM',
#    'Sun Closed'],
#   ['Salvos Narrabri Family Store',
#    '19 Doyle Street NARRABRI NSW 2390',
#    -30.3235456,
#    149.7858045,
#    'Mon - Fri 9am to 2pm'],
#   ['LifeHouse Care Op Shop - Moree',
#    '81 Heber St, Moree, NSW, 2400',
#    -29.463003,
#    149.8419618,
#    'Mon - Thu 8:30am - 3:30pm',
#    'Fri 9:00am - 12:00pm',
#    'Sat - Sun Closed'],
#   ['Salvos Moree Family Store',
#    '122-124 Heber Street MOREE NSW 2400 6752 7351',
#    None,
#    None,
#    'Wed - Fri 9am - 5pm'],
#   ['Vinnies Moree',
#    '65 Frome Street, Moree NSW 2400',
#    -29.4832128,
#    149.8497458,
#    'Mon Closed',
#    'Tue - Fri 9AM-1PM',
#    'Sat - Sun Closed'],
#   ['Hotel Lane OpShop',
#    '5 hotel lane Coolatai 2402',
#    -29.2526605,
#    150.7513122],
#   ['Vinnies Warialda',
#    '37 Geddes Street, Warialda NSW 2402',
#    -29.5428662,
#    150.5738605,
#    'Mon - Wed 9AM-12PM',
#    'Thu Closed',
#    'Fri 9AM-12PM',
#    'Sat - Sun Closed'],
#   ['Salvos Bingara Family Store',
#    '47 Maitland Street BINGARA NSW 2404',
#    -29.8693886,
#    150.5722632],
#   ['Vinnies Dungog',
#    '126-128 Dowling St , Dungog  NSW 2420',
#    -32.3984954,
#    151.75837,
#    'Mon - Fri 9AM - 3.45PM'],
#   ['St Pauls Anglican Op Shop',
#    '61 king street gloucester',
#    -32.0090567,
#    151.9643401,
#    'Mon closed',
#    'Tue 9am-3pm',
#    'Wed closed',
#    'Thu 9am-3pm',
#    'Fri closed',
#    'Sat 9am-12pm',
#    'Sun closed'],
#   ['Majestic Family Store',
#    '30 Church Street Gloucester',
#    -32.0063785,
# ...
#    'Sat 9am to 1pm',
#    'Sun Closed'],
#   ['St Faiths Op Shop',
#    '1 Sutherland Drive cnr Samsonvale Road Strathpine',
#    None,
#    None,
#    'Fri Friday 9:30am - 2pm'],
#   ["NEIGHBOUR'S AID OP SHOP",
#    'SHOP 5-9/ 690 GYMPIE ROAD, LAWNTON QLD. 4501',
#    None,
#    None,
#    'Mon - Fri 8.30 - 4PM',
#    'Sat 9.00 - 4PM',
#    'Sun CLOSED'],
#   ["Neighbour's Aid Op Shop",
#    '690 Gympie Road, Lawnton, Queensland',
#    -27.2909006,
#    152.9843458,
#    'Mon - Fri 8.30 - 4.00',
#    'Sat 9.00 -4.00',
#    'Sun Closed'],
#   ['Lifeline Shop Lawnton',
#    '666 Gympie Rd Lawnton Q 4501',
#    None,
#    None,
#    'Mon - Fri 8:30am-5pm',
#    'Sat 9am-4pm',
#    'Sun 9am-2pm'],
#   ['Vinnies Lawnton',
#    'Unit 12/690 Gympie Rd , Lawnton QLD 4501',
#    None,
#    None,
#    'Mon - Fri 8.30 AM - 4.30 PM',
#    'Sat 9:00 AM - 2:00 PM',
#    'Sun Closed'],
#   ["The Warrior's Return and First Responders Up Cycle Shop",
#    '8 Ebert Parade Lawnton Qld 4501',
#    -27.2808218,
#    152.9804724,
#    'Mon - Fri 9 am to 5 pm',
#    'Sat 10 am to 4 pm',
#    'Sun Closed'],
#   ['Salvos at Strathpine',
#    '690 Gympie Road, Lawnton QLD 4500',
#    -27.2909006,
#    152.9843458,
#    'Mon - Sat 9am - 5pm'],
#   ['Thrifty Tuesday Drop In',
#    '44 Todds Road Lawnton',
#    -27.2823977,
#    152.9778675,
#    'Tue 9am to 12pm'],
#   ['Coopernook Pop Up Op Shop',
#    '4 Petrie Street, Coopernook.  NSW.  2426',
#    -31.8217465,
#    152.6142043,
#    'Wed - Thu 9am - 2pm'],
#   ['Lifeline Shop Kallangur',
#    '1404 Anzac Avenue Kallangur QLD 4503',
#    -27.2518433,
#    152.9867282,
#    'Mon - Fri 8:30 am - 4:30 pm',
#    'Sat 9:00 am - 2.00 pm'],
#   ['Save The Children - Kallangur',
#    'Shop 1,1469 Anzac Ave Kallangur, QLD',
#    None,
#    None,
#    'Mon - Sat 9am - 4pm',
#    'Sun 10am - 4pm'],
#   ['Salvos at Kallangur',
#    '1469 Anzac Avenue, Kallangur 4503',
#    -27.2578422,
#    152.9808968,
#    'Mon - Sat'],
#   ['Kallangur Salvos',
#    '1469 Anzac Avenue KALLANGUR',
#    -27.2518433,
#    152.9867282,
#    'Mon-Sat 9am to 5pm'],
#   ['Be Uplifted Op Shop',
#    '512 Old Gympie Road Strathpine',
#    None,
#    None,
#    'Mon - Fri 9am to 4pm',
#    'Sat 9am to 2pm',
#    'Sun closed'],
#   ['Burpengary Salvos',
#    '290 Bruce Highway BURPENGARY',
#    -27.1412978,
#    152.9779962,
#    'Mon-Sat 9am to 5pm'],
#   ['Cnr North Shore Drive & Station Road Burpengary QLD 4505',
#    'Mon - Fri 8:30 am - 4:00 pm',
#    None,
#    None,
#    'Sat 9:00 am - 12:30 pm'],
#   ['Lifeline Shop Morayfield',
#    '5/343 Morayfield Rd, Morayfield',
#    -27.122518,
#    152.9571201,
#    'Mon - Fri 8:30am-5pm',
#    'Sat 9am-4pm',
#    'Sun 10am-3pm'],
#   ['Shop 1/9 Benabrow Avenue Bellara QLD 4507',
#    'Mon - Fri 8:30 am - 4:00 pm',
#    None,
#    None,
#    'Sat 8:30 am - 12:00 pm'],
#   ['Op Shop Bargain Shed',
#    '42 Foley Street Bongaree Bribie Island Qld',
#    None,
#    None,
#    'Mon - Fri 8.30 am - 1 pm',
#    'Sat - Sun closed'],
#   ['2/18 Jacana Avenue Woorim QLD 4507',
#    'Mon - Fri 9:00 am - 3:00 pm',
#    None,
#    None,
#    'Sat 9:00 am - 12:30 pm'],
#   ['Vinnies',
#    '567 Deception Bay Rd Deception Bay',
#    -27.1853796,
#    153.0056614,
#    'Mon - Fri 9am-4:30pm',
#    'Sat - Sun 9:30am-2:30pm'],
#   ['Deception Bay Red Cross',
#    'Shop 19/20 Deception Bay Shopping Centre Deception Bay, QLD 4508',
#    None,
#    None,
#    'Mon - Fri 9:00am-4:30pm',
#    'Sat - Sun 9:00am - 12:30pm'],
#   ['Link Vision',
#    '81 Bailey Rd Deception Bay',
#    -27.1850994,
#    153.0259713,
#    'Mon - Fri 8am - 4pm',
#    'Sat 9am - 3pm',
#    'Sun CLOSED'],
#   ['Church Op Shop',
#    '43 Park Rd Deception Bay',
#    -27.1850482,
#    153.0189845,
#    'Wed 9am-2pm',
#    'Sat 9-12pm Second Sat of Month'],
#   ['YMCA Op Shop Mango Hill',
#    '2/22 Halpine Drive, MANGO HILL 4509',
#    -27.2420346,
#    153.0247801,
#    'Mon - Sat 9am - 4pm',
#    'Sun 9am - 3pm'],
#   ['Footprints North Lakes',
#    '3/23 Discovery Drive North Lakes',
#    -27.2186611,
#    153.0213098,
#    'Mon - Fri 9am-5pm',
#    'Sat 9am-4pm'],
#   ['Footprints North Lakes',
#    '23 Discovery Dr, North Lakes QLD 4509',
#    -27.2168414,
#    153.0213931,
#    'Mon - Fri 9:00 am - 5:00 pm',
#    'Sat 9:00 am - 4:00 pm'],
#   ['Lifeline Shop North Lakes',
#    '109 Flinders Parade, North Lakes 4509',
#    -27.2144626,
#    152.9988928,
#    'Mon - Fri 09:00 am - 5:00 pm',
#    'Sat 09:00 am - 4:00 pm',
#    'Sun 10:00 am - 3:00 pm'],
#   ['27 King Street Caboolture QLD 4510',
#    'Mon - Fri 8:30 am - 4:00 pm',
#    None,
#    None,
#    'Sat 9:00 am - 12:00 pm'],
#   ['Shed 4 Industrial Avenue Caboolture South QLD 4506',
#    'Mon - Fri 8:30 am - 4:30 pm',
#    None,
#    None,
#    'Sat 8:30 am - 12:30 pm'],
#   ['Old Brand New',
#    '1 King St, Caboolture',
#    -27.0758586,
#    152.9278511,
#    'Mon - Fri 9am-2.30pm',
#    'Sat - Sun Closed'],
#   ['Salvos Caboolture Family Store',
#    '82 Lower King Street CABOOLTURE QLD 4510',
#    -27.0856156,
#    152.9616754,
#    'Mon - Fri 8.30am-2.30pm'],
#   ['Shed 7, Industrial Avenue Caboolture QLD 4510',
#    'Mon - Fri 8:00 am - 4:00 pm',
#    None,
#    None],
#   ['George Street Woodford QLD 4514',
#    'Mon - Fri 9:00 am - 3:30 pm',
#    None,
#    None,
#    'Sat 9:00 am - 12:00 pm'],
#   ['Kilcoy Red Cross',
#    '33 William St Kilcoy QLD 4515',
#    -26.9433453,
#    152.5568297,
#    'Mon - Fri 9:00am - 4:00pm'],
#   ['Indigo Fae Preloved Clothing Exchange',
#    '866 Beerburrum Road, Elimbah',
#    -26.9661001,
#    152.951953,
#    'Mon Closed',
#    'Tue - Fri 10am - 4pm',
#    'Sat 10am - 2pm',
#    'Sun Closed'],
#   ['Lifeline Shop Beerwah',
#    'Shop 17/60 Simpson Street Beerwah QLD 4519',
#    None,
#    None,
#    'Mon - Fri 8:45 am - 4:45 pm',
#    'Sat 9:00 am - 12:00 pm'],
#   ['Mingary Care Caloundra',
#    '47 Caloundra Road Caloundra West Qld 4551',
#    -26.7994228,
#    153.1151788,
#    'Mon - Fri 9am - 4pm',
#    'Sat 9am - 3pm',
#    'Sun Closed'],
#   ['Beautiful You Funky Op Shop',
#    '738 Nicklin Way, Currimundi, 4551 Queensland',
#    -26.7673914,
#    153.1219158,
#    'Mon - Sat 9:00 - 16:00',
#    'Sun Closed'],
#   ['Lifeline Shop Caloundra',
#    '70 Bulcock Street Caloundra QLD 4551',
#    -26.8047101,
#    153.131488,
#    'Mon - Fri 9:00 am - 4:30 pm',
#    'Sat 9:00 am - 4:00 pm',
#    'Sun 9:00 am - 2:00 pm'],
#   ['Caloundra Red Cross',
#    'Shop 3, 86 Bulcock St, Caloundra, QLD, 4551',
#    None,
#    None,
#    'Mon - Fri 9:00am-4:00pm',
#    'Sat 9:00am - 1:30pm',
#    'Sun 9:00am - 1:00pm'],
#   ['Salvos Caloundra Family Store',
#    '1/19  Bulcock Street CALOUNDRA QLD 4551;',
#    -26.8048393,
#    153.133734,
#    'Mon - Fri 8.30 - 4.00',
#    'Sat 8.30 - 2.00'],
#   ['Vinnies Caloundra',
#    '16 Mayes Avenue, Caloundra QLD 4551',
#    -26.8030265,
#    153.1225669,
#    'Mon - Fri 8.30-4.30',
#    'Sat 9.00-12:30'],
#   ['Save The Children - Caloundra',
#    'Shop 3, 28 Minchinton Street Caloundra',
#    None,
#    None,
#    'Mon - Fri 9am - 3:30pm',
#    'Sat - Sun 9am - 1pm'],
#   ['Lifeline Shop Maleny',
#    'Shop 10/43 Maple Street Maleny QLD 4552',
#    None,
#    None,
#    'Mon - Fri 9:00 am - 4:30 pm',
#    'Sat 10:00 am - 3:00 pm'],
#   ['Maleny Salvation Army Family Store',
#    'Riverside Centre, Unit 2/4 Maple St, Maleny QLD 4552',
#    None,
#    None,
#    'Mon - Fri 8.30 to 4.00',
#    'Sat 9.00 to 2.00',
#    'Sun closed'],
#   ["St Augustine's Anglican Church Op Shop",
#    '13 Hill Street Palmwoods 4555',
#    -26.6878039,
#    152.9582865,
#    'Mon Closed',
#    'Tue 9.30 - 1.00',
#    'Wed Closed',
#    'Thu 9.30 -1.00',
#    'Fri 9.30 - 1.00',
#    'Sat 9.30 -1.00',
#    'Sun Closed'],
#   ['Fusion Opshop',
#    '18/2 Ballinger Road, Buderim QLD 4556',
#    -26.7014721,
#    153.0711137,
#    'Mon - Fri 9am - 4pm',
#    'Sat 9am- 12pm',
#    'Sun Closed'],
#   ['Bloomhill Op Shop & Furniture',
#    '41 Main St, Buderim QLD 4556',
#    -26.6850802,
#    153.0527473,
#    'Mon - Fri 9am - 4.30pm',
#    'Sat 9am - 12.30pm',
#    'Sun Closed'],
#   ['608 Maroochydore Road Kunda Park QLD 4556',
#    'Mon - Fri 9:00 am - 4:00 pm',
#    None,
#    None,
#    'Sat 8:30 am - 2:30 pm'],
#   ['Neighbours Aid Community Store Mooloolaba',
#    '128 Brisbane Road; Mooloolaba',
#    -26.6945575,
#    153.115126],
#   ['Sanctuary Op Shop Mooloolaba',
#    'U2/3 Tarcoola Ave, Mooloolaba 4557',
#    None,
#    None,
#    'Mon - Tue 10 - 3 pm',
#    'Wed 10 - 3 on',
#    'Thu - Fri 10 - 3 pm',
#    'Sat Closed',
#    'Sun closed'],
#   ['Fusion Op Shop',
#    '1/95 Aerodrome Rd, Maroochydore QLD 4558',
#    -26.6610292,
#    153.1015078,
#    'Mon - Fri 8.30am to 3.30pm',
#    'Sat 8.30am to 3.00pm'],
#   ['Aus Living Support',
#    '27 Evans Street, Maroochydore QLD 4560',
#    -26.6523718,
#    153.0826709,
#    'Mon - Fri 8.30am to 4.30pm',
#    'Sat 9am to 1pm'],
#   ['CAYAC Op Shop & Care Centre',
#    '92 Aerodrome Rd, Maroochydore QLD 4558',
#    -26.6620586,
#    153.1045291,
#    'Mon - Sat 9am to 4pm',
#    'Sun closed'],
#   ['Mingary Care Maroochydore',
#    '46 Aerodrome Rd Maroochydore Qld 4558',
#    -26.6620586,
#    153.1045291,
#    'Mon - Fri 9am - 4pm',
#    'Sat 8.30am - 1pm',
#    'Sun Closed'],
#   ['Salvos Maroochydore Family Store',
#    '134 Aerodrome Road MAROOCHYDORE QLD 4558',
#    -26.6620586,
#    153.1045291],
#   ['Katie Rose Cottage Op Shop - Maroochydore',
#    'Shop 7B, 54-56 Aerodrome Road, Maroochydore',
#    None,
#    None,
#    'Mon - Fri 9.00am - 4.00pm',
#    'Sat 9.00am - 2.00pm'],
#   ['Vinnies Maroochydore',
#    'Shop 3, 1 Norval Court, Maroochydore QLD 4558',
#    None,
#    None,
#    'Mon - Fri 9.00-4.30',
#    'Sat 9.00-12.00'],
#   ['The Salvation Army Bli Bli Family Store',
#    '304 David Low Way, Bli Bli QLD 4560',
#    -26.6304351,
#    153.0377985,
#    'Mon - Fri 9am-4.30pm',
#    'Sat 9am - 1pm',
#    'Sun Closed'],
#   ['Mingary Care Bli Bli',
#    'Shop 2H Bli Bli Village Centre, 310 David Low Way Bli Bli Qld 4560',
#    None,
#    None,
#    'Mon - Fri 9am - 4pm',
#    'Sat 9am - 1pm',
#    'Sun Closed'],
#   ['Vinnies Nambour',
#    '14-22 Howard St, Nambour QLD 4560',
#    -26.627219,
#    152.9598249,
#    'Mon - Fri 8.30am - 4pm',
#    'Sat'],
#   ['Helping Children Smile Opp Shop',
#    '33 Howard St, Nambour, Qld, 4560',
#    -26.6268397,
#    152.9626956,
#    'Mon - Sat 9am - 4pm',
#    'Sun Closed'],
#   ['Aus Living Support',
#    '102 Howard street, Nambour QLD 4560',
#    -26.6268397,
#    152.9626956,
#    'Mon - Tue 8.30am-4pm',
#    'Wed 8.30am- 4pm',
#    'Thu 8.30am-4pm',
#    'Fri 8.30am- 4pm',
#    'Sat 9am-12pm',
#    'Sun Closed'],
#   ['Bloomhill Op Shop',
#    '46 Hospital Rd, Nambour QLD 4560',
#    -26.624329,
#    152.9568003,
#    'Mon - Sat 9am-2pm',
#    'Sun Closed'],
#   ['Lifeline Shop Nambour',
#    'Shop 13 Cnr Short Street & Lowe Street Nambour QLD 4560',
#    None,
#    None,
#    'Mon - Fri 8:30 am - 4:30 pm',
#    'Sat 8:30 am - 1:00 pm'],
#   ['Salvos Nambour Family Store',
#    '163 Currie St, NAMBOUR QLD 4560',
#    -26.6254896,
#    152.9588668,
#    'Mon - Fri 9:00 - 4:30',
#    'Sat 9:00 - 1:00'],
#   ['Helping Children Smile',
#    '3/81-87 Currie Street Nambour',
#    None,
#    None,
#    'Mon - Wed 9:00 to 14:00',
#    'Thu 9:00 to 15:00',
#    'Fri - Sat 9:00 to 12:00',
#    'Sun Closed'],
#   ['22a Maple Street Cooroy QLD 4563',
#    'Mon - Fri 8:30 am - 4:30 pm',
#    None,
#    None,
#    'Sat 8:30 am - 12:30 pm'],
#   ['2/708 David Low Way Pacific Paradise QLD 4564',
#    'Mon - Fri 9:00 am - 4:45 pm',
#    None,
#    None,
#    'Sat 9:30 am - 12:30 pm'],
#   ['Tewantin',
#    '6/97 Poinciana Ave, Tewantin QLD 4565',
#    -26.3906412,
#    153.0307635,
#    'Mon to Fri, 9am - 4pm',
#    'Sat 9am - 12pm'],
#   ['Lifeline Shop Tewantin',
#    '7/88 Poinciana Avenue Tewantin QLD 4565',
#    -26.3906412,
#    153.0307635,
#    'Mon - Fri 9:00 am - 5:00 pm',
#    'Sat 9:00 am - 1:00 pm'],
#   ['Katie Rose Op Shop',
#    'The Atrium, 91 Poinciana Avenue, Tewantin',
#    None,
#    None,
#    'Mon - Fri 8.30am - 4.00pm',
#    'Sat 9.00am - 12.00pm'],
#   ['Waves of Kindness Op Shop',
#    '25 Production St, Noosaville QLD 4566',
#    -26.4163289,
#    153.0451167,
#    'Mon - Fri 8.30am - 4.30pm',
#    'Sat 8.30am - 3.00pm',
#    'Sun 9.00am - 3.00pm'],
#   ['The Hub Op Shop',
#    '202 Eumundi Noosa Road, Noosaville',
#    -26.4061427,
#    153.0493015,
#    'Mon Closed',
#    'Tue 9.00 - 2.30',
#    'Wed - Fri 9.00-2.30',
#    'Sat 9.00-12.00',
#    'Sun Closed'],
#   ['Regain Hope',
#    '8/171 Eumundi-Noosa Road, Noosaville QLD 4566',
#    -26.4010747,
#    153.0512858,
#    'Mon - Fri 9:00-4:30',
#    'Sat 9:00-1:00',
#    'Sun Coolum open'],
#   ['Lifeline Shop Noosaville',
#    'Shop 2/5 Gibson Road, Noosaville QLD 4566',
#    -26.4016376,
#    153.0661356,
#    'Mon - Fri 9:00 am - 4:30 pm',
#    'Sat 9:00 am - 3:00 pm',
#    'Sun 10.00am - 2.00pm'],
#   ['Salvos Noosa Family Store',
#    '20 Eenie Creek Road NOOSAVILLE QLD 4566',
#    -26.4134106,
#    153.0511611],
#   ['Katie Rose Op Shop - Furniture Shop',
#    'Industrial Lane, 3/170 Eumundi Road, Noosaville',
#    None,
#    None,
#    'Mon - Fri 9.00am - 2.00pm'],
#   ['Lifeline Shop Pomona',
#    '14 Memorial Drive Pomona QLD 4568',
#    None,
#    None,
#    'Mon - Fri 9:00 am - 4:30 pm',
#    'Sat 9:00 am - 12:30 pm'],
#   ['Neighbours Aid Gympie',
#    '54/56 River Rd, Gympie QLD 4570',
#    -26.201481,
#    152.6710011,
#    'Mon - Fri 8:30am - 4:00pm',
#    'Sat 9:00am - 12:00noon',
#    'Sun Closed'],
#   ['Fancy That Op Shop',
#    '204 Mary St Gympie',
#    -26.1901414,
#    152.6639322,
#    'Mon - Fri 9am to 3 pm',
#    'Sat 9am to 12 Noon'],
#   ['52 Mary Street Gympie QLD 4570',
#    'Mon - Fri 9:00 am - 4:45 pm',
#    None,
#    None,
#    'Sat 9:00 am - 11:30 am'],
#   ['Vinnies Gympie',
#    '2 John Street, Gympie  QLD 4570',
#    -26.199188,
#    152.6732127,
#    'Mon - Fri 9am - 4pm',
#    'Sat - Sun 9am - 12noon'],
#   ['Gympie Red Cross',
#    '40 Mary St Gympie QLD 4570',
#    -26.189802,
#    152.6613875,
#    'Mon - Fri 9:00am-4:00pm',
#    'Sat 10:00am - 2:00pm'],
#   ['RSPCA Op Shop Gympie',
#    '18 Monkland Street, Gympie 4570',
#    -26.1875795,
#    152.6611677,
#    'Mon - Fri 9am - 4pm',
#    'Sat 9am - 1pm'],
#   ['RSPCA Op Shop',
#    '18 Monkland Street, Gympie',
#    -26.1875795,
#    152.6611677,
#    'Mon - Sat 9am to 4pm',
#    'Sun Closed'],
#   ['SRR CHARITY SHOP',
#    'Shop11/163 Mary St Condies Arcade Gympie',
#    None,
#    None,
#    'Mon 10am-3.30pm',
#    'Tue - Fri 9.30am-3.30pm',
#    'Sat 9am-2pm',
#    'Sun Closed'],
#   ['Gympie Salvation Army Family Store',
#    '42 Stumm Road SOUTHSIDE QLD 4570',
#    -26.1943759,
#    152.6427549,
#    'Mon - Fri 8:30am-4:00pm',
#    'Sat 8:00am-12:00pm',
#    'Sun Closed'],
#   ['Gympie Lions Community Op Shop',
#    '73 Mary Street Gympie',
#    -26.1889073,
#    152.6592747,
#    'Mon 8.30 - 3.30',
#    'Tue - Fri 8.30-3.30',
#    'Sat - Sun CLOSED'],
#   ['Life church care',
#    'Shop 9/125 sugar rd Maroochydore',
#    None,
#    None,
#    'Mon Closed',
#    'Tue - Sat 10-2',
#    'Sun Closed'],
#   ['Salvos Coolum Beach Family Store',
#    '4/127 Greenoaks Drive, COOLUM BEACH QLD 4573',
#    -26.5360753,
#    153.0826477,
#    'Mon - Fri 8:30 - 4pm',
#    'Sat 9am - 12pm'],
#   ['Op Shop',
#    '1/127 Greenoaks Dr, Coolum QLD 4573',
#    -26.5360753,
#    153.0826477,
#    'Mon - Fri 9am to 4pm',
#    'Sat 9am to 1pm',
#    'Sun Closed'],
#   ['Birtwell Street Coolum Beach QLD 4573',
#    'Mon - Fri 8:45 am - 4:30 pm',
#    None,
#    None,
#    'Sat 9:00 am - 1.30 pm'],
#   ['Care Outreach Care Shoppe',
#    '2/35-37 Dacmar Rd Coolum Beach',
#    None,
#    None,
#    'Mon - Fri Monday 9-3:30pm',
#    'Sat 9-12 noon',
#    'Sun Closed'],
#   ['394 Nicklin Way Bokarina QLD 4575',
#    'Mon - Fri 9:00 am - 4:45 pm',
#    None,
#    None,
#    'Sat 9:00 am - 4:00 pm',
#    'Sun 9:00 am - 3:00pm'],
#   ['Mingary Care Warana',
#    '1/3 Waterview Street Warana Qld 4575',
#    -26.7248121,
#    153.1285523,
#    'Mon - Fri 9am - 4pm',
#    'Sat 9am -1pm',
#    'Sun Closed'],
#   ['Vinnies', '84 Lamb St Murgon', -26.2402935, 151.9338464],
#   ['Lifeline Shop Murgon',
#    '80 Macalister Street Murgon QLD 4605',
#    -26.2431745,
#    151.9420544,
#    'Tue - Thu 8:00 am - 2:00 pm'],
#   ['Blue Care Murgon Thrift Shop',
#    '62 Lamb Street, Murgon, QLD, 4605',
#    -26.2420308,
#    151.9420093],
#   ['Vinnies Wondai',
#    '63-67 Haly Street, Wondai QLD 4606',
#    -26.3192025,
#    151.8703112,
#    'Mon Closed',
#    'Tue - Fri 9am-3pm',
#    'Sat - Sun Closed'],
#   ['Vinnies Op Shop',
#    '63-76 Haly St Wondai Qld',
#    -26.3148445,
#    151.8774791,
#    'Mon Closed',
#    'Tue - Fri 9am- 3pm',
#    'Sat - Sun Closed'],
#   ['Vinnies Kingaroy',
#    '48 King Street, Kingaroy QLD 4610',
#    -26.5374937,
#    151.8387277,
#    'Mon - Fri 9.00-4.00',
#    'Sat - Sun'],
#   ['Kingaroy Red Cross',
#    '209 Kingaroy St Kingaroy\tQLD\t4610',
#    -26.5427443,
#    151.8389891,
#    'Mon - Fri 9:00am - 5:00pm',
#    'Sat 9:00am - 3:00pm'],
#   ...]]

# %%
# Define custom headers
columns = [
    "name",
    "address",
    "latitude",
    "longitude",
    "hours_1",
    "hours_2",
    "hours_3"
    ]

# Normalize rows: pad with None so all rows have same length
max_len = len(columns)

normalized = []

for row in data:
    row = list(row)
    if len(row) < max_len:
        row = row + [None] * (max_len - len(row))
    else:
        row = row[:max_len]  # trim if too long
    normalized.append(row)

# Create DataFrame
df_opshop = pd.DataFrame(normalized, columns=columns)

# Show only first 5 rows
df_opshop.head(5)
# Out:
#                                                 name  \
# 0  Koo Wee Rup and District Lions Community Oppor...
# 1                        Rose Lodge Opportunity Shop
# 2                         The Green Shed Underground
# 3                          Hopeworks Seaford Op Shop
# 4                                     The Collective
#
#                                              address   latitude   longitude  \
# 0                     290 Rossiter Road, Koo Wee Rup -38.199341  145.491249
# 1                 42 McBride Avenue, Wonthaggi, 3996 -38.606322  145.590925
# 2  Basement level, 34 E Row Canberra ACT 2601 Aus...        NaN         NaN
# 3            2/36 Hartnett Dr 3198 Seaford, Victoria -38.113295  145.141560
# 4                     270 Rossiter Road, Koo Wee Rup -38.199690  145.490323
#
#                    hours_1             hours_2                        hours_3
# 0       Mon - Fri 10am-4pm        Sat 9am-12pm  Sun 10am-3pm selected Sundays
# 1      Mon - Fri 9am - 4pm      Sat 9am - 12pm                            NaN
# 2  Tue - Fri 10:30am - 6pm   Sat 10:30am - 4pm                            NaN
# 3        Mon - Fri 9am-4pm         Sat 9am-3pm                     Sun CLOSED
# 4       Mon - Tue 10am-4pm  Fri - Sun 10am-4pm                            NaN
