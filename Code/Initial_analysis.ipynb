# %%
# Import Library
import os

## Universal Data Processing
import numpy as np
import pandas as pd

## Regular Expression for Text Data
import re

## JSON Files Manipulation
import json

# %%
# Path
path = os.path.join("C:\03. Other\op-shops\Datasets\opshops_with_coords.json")

# Load each datasets
all_data = []

for idx, path in enumerate(paths):              
    print(f"Loading file {idx}: {path}")
    with open(path, "r", encoding="utf-8") as json_file:
        data_idx = json.load(json_file)
        all_data.append(data_idx)

print("Files loaded", len(all_data))
